# %% [markdown]
# https://gallery.pangeo.io/repos/NCAR/notebook-gallery/notebooks/Run-Anywhere/Ocean-Heat-Content/OHC_tutorial.html

# %%
from dask.distributed import Client

# %%
client = Client()  # set up local cluster on your laptop
client
# Out:
# <Client: 'tcp://127.0.0.1:51010' processes=5 threads=10, memory=64.00 GiB>

# %%
import matplotlib.pyplot as plt  # plotting library
import numpy as np  # numerical library
import xarray as xr  # netCDF library
import cartopy  # Map projections libary
import cartopy.crs as ccrs  # Projections list
import cftime
import pandas as pd

# %%
# Some defaults
plt.rcParams['figure.figsize'] = (12, 5)  # Default plot size

# %%
file='./Data/RG_Global_2004-01_2024-03.nc'

# %%
ds = xr.open_dataset(file, chunks = {'time': 8})

# %%
ds
# Out:
# <xarray.Dataset> Size: 6GB
# Dimensions:      (time: 243, pre: 58, lat: 145, lon: 360)
# Coordinates:
#   * lon          (lon) float32 1kB 20.5 21.5 22.5 23.5 ... 377.5 378.5 379.5
#   * lat          (lat) float32 580B -64.5 -63.5 -62.5 -61.5 ... 77.5 78.5 79.5
#   * pre          (pre) float32 232B 2.5 10.0 20.0 ... 1.8e+03 1.9e+03 1.975e+03
#   * time         (time) datetime64[ns] 2kB 2004-01-15 2004-02-15 ... 2024-03-15
# Data variables:
#     temperature  (time, pre, lat, lon) float32 3GB dask.array<chunksize=(8, 58, 145, 360), meta=np.ndarray>
#     salinity     (time, pre, lat, lon) float32 3GB dask.array<chunksize=(8, 58, 145, 360), meta=np.ndarray>
# Attributes:
#     description:  Roemmich-Gilson Argo Climatology

# %%
from dask.utils import format_bytes

# %%
ds['temperature'].shape
# Out:
# (243, 58, 145, 360)

# %%
ds.chunks
# Out:
# Frozen({'time': (8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 3), 'pre': (58,), 'lat': (145,), 'lon': (360,)})

# %%
n=16
format_bytes(n*58*145*360*15)
# Out:
# '692.96 MiB'

# %%
da = ds['temperature']

# %%
da
# Out:
# <xarray.DataArray 'temperature' (time: 243, pre: 58, lat: 145, lon: 360)> Size: 3GB
# dask.array<open_dataset-temperature, shape=(243, 58, 145, 360), dtype=float32, chunksize=(8, 58, 145, 360), chunktype=numpy.ndarray>
# Coordinates:
#   * lon      (lon) float32 1kB 20.5 21.5 22.5 23.5 ... 376.5 377.5 378.5 379.5
#   * lat      (lat) float32 580B -64.5 -63.5 -62.5 -61.5 ... 76.5 77.5 78.5 79.5
#   * pre      (pre) float32 232B 2.5 10.0 20.0 30.0 ... 1.8e+03 1.9e+03 1.975e+03
#   * time     (time) datetime64[ns] 2kB 2004-01-15 2004-02-15 ... 2024-03-15

# %%
import cf_units as cf

# %%
level_point = ds.pre[0]
level_point
# Out:
# <xarray.DataArray 'pre' ()> Size: 4B
# array(2.5, dtype=float32)
# Coordinates:
#     pre      float32 4B 2.5

# %%
target_units = cf.Unit('km')
orig_units.convert(level_point, target_units)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 target_units = cf.Unit('km')
# ----> 2 orig_units.convert(level_point, target_units)
#
# NameError: name 'orig_units' is not defined

# %%
def sum_variables(variable1, variable2):
    variable_sum = variable1 + variable2
    return variable_sum

# %%
variable1 = 0
variable2 = 1
output_variable = sum_variables(variable1, variable2)

# %%
output_variable
# Out:
# 1
